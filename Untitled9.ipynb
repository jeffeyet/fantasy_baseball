# %%
pip install requests requests_oauthlib
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests_oauthlib) (3.3.1)

# %%
import os

os.environ["YAHOO_CONSUMER_KEY"] = "dj0yJmk9T2ZNbnUwU0xXUG9oJmQ9WVdrOVNYRm1ORmcwTkVRbWNHbzlNQT09JnM9Y29uc3VtZXJzZWNyZXQmc3Y9MCZ4PWVh"
os.environ["YAHOO_CONSUMER_SECRET"] = "e135982043b464c2a371e2be2b60c2524c3cd48b"

# %%
import json
import os
from requests_oauthlib import OAuth1Session

# 1) Paste your Consumer Key/Secret here (AFTER you regenerate the secret)
CONSUMER_KEY = os.environ["YAHOO_CONSUMER_KEY"].strip()
CONSUMER_SECRET = os.environ["YAHOO_CONSUMER_SECRET"].strip()

# Yahoo OAuth 1.0a endpoints used in the Fantasy Sports guide
REQUEST_TOKEN_URL = "https://api.login.yahoo.com/oauth/v2/get_request_token"
ACCESS_TOKEN_URL  = "https://api.login.yahoo.com/oauth/v2/get_token"

TOKEN_FILE = "yahoo_tokens.json"

def save_tokens(tokens: dict) -> None:
    with open(TOKEN_FILE, "w") as f:
        json.dump(tokens, f, indent=2)

def load_tokens():
    if os.path.exists(TOKEN_FILE):
        with open(TOKEN_FILE, "r") as f:
            return json.load(f)
    return None

def get_oauth_session(tokens=None):
    if tokens:
        return OAuth1Session(
            CONSUMER_KEY,
            client_secret=CONSUMER_SECRET,
            resource_owner_key=tokens["oauth_token"],
            resource_owner_secret=tokens["oauth_token_secret"],
        )
    return OAuth1Session(CONSUMER_KEY, client_secret=CONSUMER_SECRET)

def main():
    # If we already have tokens, try using them first
    tokens = load_tokens()
    if tokens:
        print("Found saved tokens. We'll try an API call with them.\n")
        sess = get_oauth_session(tokens)
    else:
        # 2) Get request token (use 'oob' = out-of-band verifier copy/paste)
        sess = get_oauth_session()
        rt = sess.fetch_request_token(REQUEST_TOKEN_URL, params={"oauth_callback": "oob"})
        request_token = rt["oauth_token"]
        request_secret = rt["oauth_token_secret"]

        # 3) Send user to authorize URL (Yahoo returns this URL in the response)
        auth_url = rt.get("xoauth_request_auth_url")
        if not auth_url:
            # fallback (rare), but keep you moving:
            auth_url = f"https://api.login.yahoo.com/oauth/v2/request_auth?oauth_token={request_token}"

        print("1) Open this URL in your browser and approve access:\n")
        print(auth_url, "\n")
        verifier = input("2) Paste the verifier code Yahoo shows you here: ").strip()

        # 4) Exchange request token + verifier for access token
        sess = OAuth1Session(
            CONSUMER_KEY,
            client_secret=CONSUMER_SECRET,
            resource_owner_key=request_token,
            resource_owner_secret=request_secret,
            verifier=verifier,
        )
        at = sess.fetch_access_token(ACCESS_TOKEN_URL)
        tokens = {
            "oauth_token": at["oauth_token"],
            "oauth_token_secret": at["oauth_token_secret"],
            # Yahoo may also return oauth_session_handle for token refresh workflows
            "oauth_session_handle": at.get("oauth_session_handle"),
        }
        save_tokens(tokens)
        print("\nSaved access tokens to yahoo_tokens.json\n")

    # 5) First “proof it works” call: list your MLB leagues
    # Yahoo Fantasy Sports API returns XML by default; format=json makes life easier.
    url = "https://fantasysports.yahooapis.com/fantasy/v2/users;use_login=1/games;game_keys=mlb/leagues?format=json"
    resp = sess.get(url)
    print("Status:", resp.status_code)
    print(resp.text[:2000])  # print first chunk so output isn't overwhelming

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TokenRequestDenied                        Traceback (most recent call last)
# /tmp/ipython-input-1815543371.py in <cell line: 0>()
#      82
#      83 if __name__ == "__main__":
# ---> 84     main()
#
# /tmp/ipython-input-1815543371.py in main()
#      42         # 2) Get request token (use 'oob' = out-of-band verifier copy/paste)
#      43         sess = get_oauth_session()
# ---> 44         rt = sess.fetch_request_token(REQUEST_TOKEN_URL, params={"oauth_callback": "oob"})
#      45         request_token = rt["oauth_token"]
#      46         request_secret = rt["oauth_token_secret"]
#
# /usr/local/lib/python3.12/dist-packages/requests_oauthlib/oauth1_session.py in fetch_request_token(self, url, realm, **request_kwargs)
#     280         """
#     281         self._client.client.realm = " ".join(realm) if realm else None
# --> 282         token = self._fetch_token(url, **request_kwargs)
#     283         log.debug("Resetting callback_uri and realm (not needed in next phase).")
#     284         self._client.client.callback_uri = None
#
# /usr/local/lib/python3.12/dist-packages/requests_oauthlib/oauth1_session.py in _fetch_token(self, url, **request_kwargs)
#     362         if r.status_code >= 400:
#     363             error = "Token request failed with code %s, response was '%s'."
# --> 364             raise TokenRequestDenied(error % (r.status_code, r.text), r)
#     365
#     366         log.debug('Decoding token from response "%s"', r.text)
#
# TokenRequestDenied: Token request failed with code 401, response was 'Unauthorized'.

# %%
# !pip -q install requests requests_oauthlib

from requests_oauthlib import OAuth1Session

REQUEST_TOKEN_URL = "https://api.login.yahoo.com/oauth/v2/get_request_token"

oauth = OAuth1Session(CONSUMER_KEY, client_secret=CONSUMER_SECRET)

r = oauth.post(REQUEST_TOKEN_URL, data={"oauth_callback": "oob"})
print("Status:", r.status_code)
print("Body:", r.text[:400])
# Out:
# Status: 401
# Body: Unauthorized
